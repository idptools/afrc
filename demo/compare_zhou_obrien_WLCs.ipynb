# %%
from afrc.polymer_models.wlc import WormLikeChain as WLC_Zhou
from afrc.polymer_models.wlc2 import WormLikeChain2 as WLC_OBrien
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

# %%
figure(num=None, figsize=(4,2), dpi=350)
for l in np.arange(40,300,20):
    
    seq='A'*l

    model = WLC_Zhou(seq,)
    v = model.get_end_to_end_distribution()
    plt.plot(v[0], v[1], color='k', alpha=0.3,linewidth=0.5)
    
    e2e = model.get_mean_end_to_end_distance()
    #plt.plot([e2e,e2e],[np.max(v[1]), np.max(v[1])], 'ok', alpha=0.5, ms=4, mew=0)
    
    
    model = WLC_OBrien(seq)
    v = model.get_end_to_end_distribution()
    plt.plot(v[0], v[1], color='r', alpha=0.3,linewidth=0.5)
    
    e2e = model.get_mean_end_to_end_distance()

    

    
plt.xlabel('r (A)',fontsize=8)
plt.ylabel('P(r)', fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlim([0, 200])
plt.ylim([0, 0.002])
plt.legend(['Zhou','OBrien'],frameon=False,fontsize=7)
